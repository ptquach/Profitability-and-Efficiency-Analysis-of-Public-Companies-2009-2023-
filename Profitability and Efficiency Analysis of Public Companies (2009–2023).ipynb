# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: /usr/share/pip-wheels
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv("Financial Statements.csv")
df.head()
# Out:
#    Year Company  Category  Market Cap(in B USD)   Revenue  Gross Profit  \
# 0  2022     AAPL       IT               2066.94  394328.0      170782.0
# 1  2021     AAPL       IT               2913.28  365817.0      152836.0
# 2  2020     AAPL       IT               2255.97  274515.0      104956.0
# 3  2019     AAPL       IT               1304.76  260174.0       98392.0
# 4  2018     AAPL       IT                748.54  265595.0      101839.0
#
#    Net Income  Earning Per Share    EBITDA  Share Holder Equity  ...  \
# 0     99803.0               6.11  130541.0              50672.0  ...
# 1     94680.0               5.61  120233.0              63090.0  ...
# 2     57411.0               3.28   77344.0              65339.0  ...
# 3     55256.0               2.97   76477.0              90488.0  ...
# 4     59531.0               2.98   81801.0             107147.0  ...
#
#    Current Ratio  Debt/Equity Ratio       ROE      ROA      ROI  \
# ...

# %%
df.dtypes
# Out:
# Year                                     int64
# Company                                 object
# Category                                object
# Market Cap(in B USD)                   float64
# Revenue                                float64
# Gross Profit                           float64
# Net Income                             float64
# Earning Per Share                      float64
# EBITDA                                 float64
# Share Holder Equity                    float64
# Cash Flow from Operating               float64
# Cash Flow from Investing               float64
# Cash Flow from Financial Activities    float64
# Current Ratio                          float64
# Debt/Equity Ratio                      float64
# ROE                                    float64
# ROA                                    float64
# ROI                                    float64
# Net Profit Margin                      float64
# Free Cash Flow per Share               float64
# ...

# %%
print(df.columns.tolist())
# Out:
# ['Year', 'Company ', 'Category', 'Market Cap(in B USD)', 'Revenue', 'Gross Profit', 'Net Income', 'Earning Per Share', 'EBITDA', 'Share Holder Equity', 'Cash Flow from Operating', 'Cash Flow from Investing', 'Cash Flow from Financial Activities', 'Current Ratio', 'Debt/Equity Ratio', 'ROE', 'ROA', 'ROI', 'Net Profit Margin', 'Free Cash Flow per Share', 'Return on Tangible Equity', 'Number of Employees', 'Inflation Rate(in US)']

# %%
df.columns = df.columns.str.strip()

# %%
 averageROE = df.groupby('Company')['ROE'].mean().sort_values(ascending=False)

# %%
print("The highest average ROE companies are:\n")
print(averageROE)
# Out:
# The highest average ROE companies are:
#
# Company
# AAPL     61.273936
# MSFT     32.427673
# INTC     19.912079
# NVDA     19.113547
# GOOG     17.108457
# SHLDQ    16.694970
# PYPL     12.745467
# AMZN     11.197943
# BCS       5.043157
# AIG       4.069250
# PCG      -8.768300
# MCD     -42.205129
# Name: ROE, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=df, x='Year', y='ROE', hue='Company', marker='o')

plt.title('ROE over the years')
plt.ylabel('Return of Equity (%)')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=df, x='Year', y='Net Profit Margin', hue='Company', marker='o')

plt.title('Net Profit Margin Trend')
plt.ylabel('Net Profit Margin (%)')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
 averageROA = df.groupby('Company')['ROA'].mean().sort_values(ascending=False)

# %%
print("The highest average ROA companies are:\n")
print(averageROA)
# Out:
# The highest average ROA companies are:
#
# Company
# AAPL     19.139679
# MSFT     14.825287
# MCD      14.299457
# GOOG     13.136229
# NVDA     12.286560
# INTC     12.188400
# PYPL      4.319878
# AMZN      3.333736
# AIG       0.745786
# BCS       0.241150
# PCG       0.046929
# SHLDQ    -7.673860
# Name: ROA, dtype: float64

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=df, x='Year', y='ROA', hue='Company', marker='o')

plt.title('ROA over the years')
plt.ylabel('Return of Assets (%)')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
averageROI = df.groupby('Company')['ROI'].mean().sort_values(ascending=False)

# %%
print("The highest average ROI companies are:\n")
print(averageROI)
# Out:
# The highest average ROI companies are:
#
# Company
# AAPL     33.561036
# MSFT     24.588320
# MCD      19.728271
# GOOG     16.549307
# INTC     15.822121
# NVDA     15.338007
# PYPL     10.635922
# AMZN      8.480193
# AIG       3.265943
# BCS       1.105693
# SHLDQ    -0.252180
# PCG     -11.312493
# Name: ROI, dtype: float64

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=df, x='Year', y='ROI', hue='Company', marker='o')

plt.title('ROI over the years')
plt.ylabel('Return of Investment (%)')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
df['Profitability Score'] = df[['ROE', 'ROA', 'ROI', 'Net Profit Margin']].mean(axis=1)
print(df['Profitability Score'])
# Out:
# 0      79.315075
# 1      64.477800
# 2      40.377750
# 3      32.234225
# 4      30.971650
#          ...
# 156     1.494925
# 157    -0.251400
# 158     4.954750
# 159     9.988350
# 160    11.131650
# Name: Profitability Score, Length: 161, dtype: float64

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['Debt/Equity Ratio'], df['Profitability Score'], alpha=0.7)
plt.xlabel('Debt/Equity Ratio')
plt.ylabel('Profitabilitys Score')
plt.title('Leverage vs Profitability')
plt.grid(True)
plt.show()

# %%
df[['Inflation Rate(in US)', 'ROE', 'ROA', 'ROI', 'Net Profit Margin']].corr()
# Out:
#                        Inflation Rate(in US)       ROE       ROA       ROI  \
# Inflation Rate(in US)               1.000000  0.043448  0.132666  0.056215
# ROE                                 0.043448  1.000000  0.244287  0.081086
# ROA                                 0.132666  0.244287  1.000000  0.051268
# ROI                                 0.056215  0.081086  0.051268  1.000000
# Net Profit Margin                   0.208630  0.245831  0.822834  0.128105
#
#                        Net Profit Margin
# Inflation Rate(in US)           0.208630
# ROE                             0.245831
# ROA                             0.822834
# ROI                             0.128105
# Net Profit Margin               1.000000

# %%
sns.heatmap(
    df[['Inflation Rate(in US)', 'ROE', 'ROA', 'ROI', 'Net Profit Margin']].corr(),
    annot=True, cmap='coolwarm'
)
plt.title("Correlation between Inflation and Profitability Metrics")
plt.show()

# %%
df[['Inflation Rate(in US)', 'Profitability Score']].corr()
# Out:
#                        Inflation Rate(in US)  Profitability Score
# Inflation Rate(in US)               1.000000             0.098834
# Profitability Score                 0.098834             1.000000

# %%
df_avg = df.groupby('Year')[['Inflation Rate(in US)', 'Profitability Score']].mean().reset_index()

import matplotlib.pyplot as plt

plt.plot(df_avg['Year'], df_avg['Inflation Rate(in US)'], label='Inflation', color='gray', linestyle='--')
plt.plot(df_avg['Year'], df_avg['Profitability Score'], label='Avg Profitability Score', marker='o')

plt.title('Inflation vs Profitability Score (Avg Across Companies)')
plt.xlabel('Year')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.scatter(df['Inflation Rate(in US)'], df['Profitability Score'], alpha=0.6)
plt.title('Inflation vs Profitability Score (All Companies, All Years)')
plt.xlabel('Inflation Rate (%)')
plt.ylabel('Profitability Score')
plt.grid(True)
plt.show()

# %%
df.to_csv("Profitability_Efficiency_Final.csv", index=False)
